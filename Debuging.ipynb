# %%
#Debug 1
x = 10
if x = 5:
    print("Hello")
# Out:
#   File "/tmp/ipython-input-1440963792.py", line 3
#     if x = 5:
#        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
#Debug 2
for i in range(5)
print(i)
# Out:
#   File "/tmp/ipython-input-423913236.py", line 2
#     for i in range(5)
#                      ^
# SyntaxError: expected ':'

# %%
#Debug 3
nama = input("Masukkan nama:")
if nama.lower = "Syifa":
    print("Halo Syifa!")
# Out:
#   File "/tmp/ipython-input-380888903.py", line 3
#     if nama.lower = "Syifa":
#        ^
# SyntaxError: cannot assign to attribute here. Maybe you meant '==' instead of '='?

# %%
#Debug 4
angka = [1,2,3,4]
print(angka[4])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-833549661.py in <cell line: 0>()
#       1 #Debug 4
#       2 angka = [1,2,3,4]
# ----> 3 print(angka[4])
#
# IndexError: list index out of range

# %%
#Debug 5
for i in range(1,10):
print("tes")
# Out:
#   File "/tmp/ipython-input-2574619040.py", line 3
#     print("tes")
#     ^
# IndentationError: expected an indented block after 'for' statement on line 2

# %%
#Debug 6
i = 0
while i < 5:
print(i)
i += 1
# Out:
#   File "/tmp/ipython-input-1051474826.py", line 4
#     print(i)
#     ^
# IndentationError: expected an indented block after 'while' statement on line 3

# %%
#Debug 7
x = int(input("Masukkan angka: "))
if x > 10:
    print("besar")
else:
    print(kecil)
# Out:
# Masukkan angka: 3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3360163959.py in <cell line: 0>()
#       4     print("besar")
#       5 else:
# ----> 6     print(kecil)
#
# NameError: name 'kecil' is not defined

# %%
#Debug 8
total = 0
for n in 10:
    total += n
print(total)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1514556261.py in <cell line: 0>()
#       1 #Debug 8
#       2 total = 0
# ----> 3 for n in 10:
#       4     total += n
#       5 print(total)
#
# TypeError: 'int' object is not iterable

# %%
#Debug 9
text = "python"
for i in range(len(text)):
    if text[i] = "o":
        print("ketemu!")
# Out:
#   File "/tmp/ipython-input-3091637018.py", line 4
#     if text[i] = "o":
#        ^
# SyntaxError: cannot assign to subscript here. Maybe you meant '==' instead of '='?

# %%
#Debug 10
while True
    print("loop")
# Out:
#   File "/tmp/ipython-input-2146581712.py", line 2
#     while True
#               ^
# SyntaxError: expected ':'
